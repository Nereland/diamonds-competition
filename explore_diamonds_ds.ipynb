# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
diam = pd.read_csv("inputs/train.csv")

# %%
diam.isna().sum() #No null values
diam.shape
# Out:
# (40455, 11)

# %%
diam.columns
# Out:
# Index(['id', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y',
#        'z', 'price'],
#       dtype='object')

# %%
diam.dtypes
# Out:
# id           int64
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
diam.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   0.30  Very Good     F     VS2   62.8   56.0  4.29  4.31  2.70    605
# 1   1   0.34      Ideal     E     SI1   62.6   55.0  4.46  4.49  2.80    565
# 2   2   0.40  Very Good     D     SI1   60.3   62.0  4.70  4.75  2.85    720
# 3   3   0.40    Premium     H     VS1   61.8   59.2  4.72  4.74  2.92    793
# 4   4   0.90  Very Good     D     SI1   61.0   63.0  6.10  6.13  3.73   4381

# %% [markdown]
# Everything that I will transform, I will do it following this order: the worst value is 1, and all categories will follow this rule.

# %%
diam.carat.unique() #cathegorize: very_low, low, medium, high, very_high (1-5)
diam.carat.min(), diam.carat.max() #0.2 - 4.5
# Out:
# (0.2, 4.5)

# %%
diam.cut.unique()
# Out:
# array(['Very Good', 'Ideal', 'Premium', 'Good', 'Fair'], dtype=object)

# %%
diam.color.unique()#J is worst, D is best.
# Out:
# array(['F', 'E', 'D', 'H', 'G', 'J', 'I'], dtype=object)

# %%
 diam.clarity.unique()#(I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
# Out:
# array(['VS2', 'SI1', 'VS1', 'SI2', 'VVS2', 'VVS1', 'IF', 'I1'],
#       dtype=object)

# %%
#diam.depth.unique()

# %%
#diam.table.unique()

# %%
diam.describe()
# Out:
#                  id         carat         depth         table             x  \
# count  40455.000000  40455.000000  40455.000000  40455.000000  40455.000000
# mean   20227.000000      0.797150     61.746612     57.453561      5.729391
# std    11678.496907      0.472872      1.431006      2.235668      1.121283
# min        0.000000      0.200000     43.000000     43.000000      0.000000
# 25%    10113.500000      0.400000     61.000000     56.000000      4.710000
# 50%    20227.000000      0.700000     61.800000     57.000000      5.700000
# 75%    30340.500000      1.040000     62.500000     59.000000      6.540000
# max    40454.000000      4.500000     79.000000     95.000000     10.230000
#
#                   y             z         price
# count  40455.000000  40455.000000  40455.000000
# mean       5.733217      3.537644   3928.715264
# std        1.151076      0.709557   3985.070609
# min        0.000000      0.000000    326.000000
# 25%        4.720000      2.910000    946.500000
# 50%        5.710000      3.530000   2398.000000
# 75%        6.540000      4.040000   5328.500000
# max       58.900000     31.800000  18818.000000

# %%
diam
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.30  Very Good     F     VS2   62.8   56.0  4.29  4.31  2.70
# 1          1   0.34      Ideal     E     SI1   62.6   55.0  4.46  4.49  2.80
# 2          2   0.40  Very Good     D     SI1   60.3   62.0  4.70  4.75  2.85
# 3          3   0.40    Premium     H     VS1   61.8   59.2  4.72  4.74  2.92
# 4          4   0.90  Very Good     D     SI1   61.0   63.0  6.10  6.13  3.73
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 40450  40450   0.32      Ideal     D     VS1   61.5   56.0  4.41  4.43  2.72
# 40451  40451   0.30      Ideal     D     VS2   60.9   57.0  4.32  4.35  2.64
# 40452  40452   0.47    Premium     G     SI1   62.7   58.0  4.97  4.99  3.12
# 40453  40453   0.40       Good     G     VS2   63.5   56.0  4.68  4.70  2.98
# 40454  40454   2.02  Very Good     H     SI2   62.3   58.0  7.97  8.04  4.99
#
#        price
# 0        605
# 1        565
# 2        720
# 3        793
# 4       4381
# ...      ...
# 40450    862
# 40451    710
# 40452    931
# 40453    807
# 40454  15064
#
# [40455 rows x 11 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
diam["labcol"] = le.fit_transform(diam["color"])
diam["labcol"]
# Out:
# 0        2
# 1        1
# 2        0
# 3        4
# 4        0
#         ..
# 40450    0
# 40451    0
# 40452    3
# 40453    3
# 40454    4
# Name: labcol, Length: 40455, dtype: int64

# %%
le = preprocessing.LabelEncoder()
diam["labcut"] = le.fit_transform(diam["cut"])
diam["labcut"]
# Out:
# 0        4
# 1        2
# 2        4
# 3        3
# 4        4
#         ..
# 40450    2
# 40451    2
# 40452    3
# 40453    1
# 40454    4
# Name: labcut, Length: 40455, dtype: int64

# %%
le = preprocessing.LabelEncoder()
diam["labclar"] = le.fit_transform(diam["clarity"])
diam["labclar"]
# Out:
# 0        5
# 1        2
# 2        2
# 3        4
# 4        2
#         ..
# 40450    4
# 40451    5
# 40452    2
# 40453    5
# 40454    3
# Name: labclar, Length: 40455, dtype: int64

# %%
diam
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.30  Very Good     F     VS2   62.8   56.0  4.29  4.31  2.70
# 1          1   0.34      Ideal     E     SI1   62.6   55.0  4.46  4.49  2.80
# 2          2   0.40  Very Good     D     SI1   60.3   62.0  4.70  4.75  2.85
# 3          3   0.40    Premium     H     VS1   61.8   59.2  4.72  4.74  2.92
# 4          4   0.90  Very Good     D     SI1   61.0   63.0  6.10  6.13  3.73
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 40450  40450   0.32      Ideal     D     VS1   61.5   56.0  4.41  4.43  2.72
# 40451  40451   0.30      Ideal     D     VS2   60.9   57.0  4.32  4.35  2.64
# 40452  40452   0.47    Premium     G     SI1   62.7   58.0  4.97  4.99  3.12
# 40453  40453   0.40       Good     G     VS2   63.5   56.0  4.68  4.70  2.98
# 40454  40454   2.02  Very Good     H     SI2   62.3   58.0  7.97  8.04  4.99
#
#        price  labcol  labcut  labclar
# 0        605       2       4        5
# 1        565       1       2        2
# 2        720       0       4        2
# 3        793       4       3        4
# 4       4381       0       4        2
# ...      ...     ...     ...      ...
# 40450    862       0       2        4
# 40451    710       0       2        5
# 40452    931       3       3        2
# 40453    807       3       1        5
# 40454  15064       4       4        3
#
# [40455 rows x 14 columns]

# %%
diam.drop(["id", "cut", "color", "clarity"], axis=1, inplace = True)

# %%
diam
# Out:
#        carat  depth  table     x     y     z  price  labcol  labcut  labclar
# 0       0.30   62.8   56.0  4.29  4.31  2.70    605       2       4        5
# 1       0.34   62.6   55.0  4.46  4.49  2.80    565       1       2        2
# 2       0.40   60.3   62.0  4.70  4.75  2.85    720       0       4        2
# 3       0.40   61.8   59.2  4.72  4.74  2.92    793       4       3        4
# 4       0.90   61.0   63.0  6.10  6.13  3.73   4381       0       4        2
# ...      ...    ...    ...   ...   ...   ...    ...     ...     ...      ...
# 40450   0.32   61.5   56.0  4.41  4.43  2.72    862       0       2        4
# 40451   0.30   60.9   57.0  4.32  4.35  2.64    710       0       2        5
# 40452   0.47   62.7   58.0  4.97  4.99  3.12    931       3       3        2
# 40453   0.40   63.5   56.0  4.68  4.70  2.98    807       3       1        5
# 40454   2.02   62.3   58.0  7.97  8.04  4.99  15064       4       4        3
#
# [40455 rows x 10 columns]

# %%
correldiam = diam.corr()
sns.heatmap(correldiam, cmap="YlGnBu")

# %%
diam.drop(["depth", "table", "labcut", "labclar"], axis=1, inplace = True)

# %%
diam
# Out:
#        carat     x     y     z  price  labcol
# 0       0.30  4.29  4.31  2.70    605       2
# 1       0.34  4.46  4.49  2.80    565       1
# 2       0.40  4.70  4.75  2.85    720       0
# 3       0.40  4.72  4.74  2.92    793       4
# 4       0.90  6.10  6.13  3.73   4381       0
# ...      ...   ...   ...   ...    ...     ...
# 40450   0.32  4.41  4.43  2.72    862       0
# 40451   0.30  4.32  4.35  2.64    710       0
# 40452   0.47  4.97  4.99  3.12    931       3
# 40453   0.40  4.68  4.70  2.98    807       3
# 40454   2.02  7.97  8.04  4.99  15064       4
#
# [40455 rows x 6 columns]

# %%
import numpy as np
from scipy import stats
diam_noout = diam[(np.abs(stats.zscore(diam)) < 3).all(axis=1)]

# %%
diam_noout
# Out:
#        carat     x     y     z  price  labcol
# 0       0.30  4.29  4.31  2.70    605       2
# 1       0.34  4.46  4.49  2.80    565       1
# 2       0.40  4.70  4.75  2.85    720       0
# 3       0.40  4.72  4.74  2.92    793       4
# 4       0.90  6.10  6.13  3.73   4381       0
# ...      ...   ...   ...   ...    ...     ...
# 40450   0.32  4.41  4.43  2.72    862       0
# 40451   0.30  4.32  4.35  2.64    710       0
# 40452   0.47  4.97  4.99  3.12    931       3
# 40453   0.40  4.68  4.70  2.98    807       3
# 40454   2.02  7.97  8.04  4.99  15064       4
#
# [39392 rows x 6 columns]

# %%
diam_noout.to_csv("outputs/diam_no_out.csv",index = False)
diam.to_csv("outputs/diam.csv", index = False)
